# %%
import requests
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/OpenExoplanetCatalogue/oec_tables/master/comma_separated/open_exoplanet_catalogue.txt'
response = requests.get(url)
part = response.text.split('on\r\n# \r\n')
len(part)
# Out:
# 2

# %%
column_list = pd.DataFrame.from_csv('oec.csv').columns.tolist()
column_list
# Out:
# ['TypeFlag',
#  'PlanetaryMassJpt',
#  'RadiusJpt',
#  'PeriodDays',
#  'SemiMajorAxisAU',
#  'Eccentricity',
#  'PeriastronDeg',
#  'LongitudeDeg',
#  'AscendingNodeDeg',
#  'InclinationDeg',
#  'SurfaceTempK',
#  'AgeGyr',
#  'DiscoveryMethod',
#  'DiscoveryYear',
#  'LastUpdated',
#  'RightAscension',
#  'Declination',
#  'DistFromSunParsec',
#  'HostStarMassSlrMass',
#  'HostStarRadiusSlrRad',
#  'HostStarMetallicity',
#  'HostStarTempK',
#  'HostStarAgeGyr',
#  'ListsPlanetIsOn']

# %%
column_list.insert(0, 'PlanetIdentifier')
column_list
# Out:
# ['PlanetIdentifier',
#  'TypeFlag',
#  'PlanetaryMassJpt',
#  'RadiusJpt',
#  'PeriodDays',
#  'SemiMajorAxisAU',
#  'Eccentricity',
#  'PeriastronDeg',
#  'LongitudeDeg',
#  'AscendingNodeDeg',
#  'InclinationDeg',
#  'SurfaceTempK',
#  'AgeGyr',
#  'DiscoveryMethod',
#  'DiscoveryYear',
#  'LastUpdated',
#  'RightAscension',
#  'Declination',
#  'DistFromSunParsec',
#  'HostStarMassSlrMass',
#  'HostStarRadiusSlrRad',
#  'HostStarMetallicity',
#  'HostStarTempK',
#  'HostStarAgeGyr',
#  'ListsPlanetIsOn']

# %%
compare_column_list = part[0].split('\r\n')[5:]
for index,item in enumerate(compare_column_list):
    #print(item)
    print(item.split(':')[1] + '-' + column_list[index])
# Out:
#  Primary identifier of planet-PlanetIdentifier
#  Binary flag [0=no known stellar binary companion; 1=P-type binary (circumbinary); 2=S-type binary; 3=orphan planet (no star)]-TypeFlag
#  Planetary mass [Jupiter masses]-PlanetaryMassJpt
#  Radius [Jupiter radii]-RadiusJpt
#  Period [days]-PeriodDays
#  Semi-major axis [Astronomical Units]-SemiMajorAxisAU
#  Eccentricity-Eccentricity
#  Periastron [degree]-PeriastronDeg
#  Longitude [degree]-LongitudeDeg
#  Ascending node [degree]-AscendingNodeDeg
#  Inclination [degree]-InclinationDeg
#  Surface or equilibrium temperature [K]-SurfaceTempK
#  Age [Gyr]-AgeGyr
#  Discovery method-DiscoveryMethod
#  Discovery year [yyyy]-DiscoveryYear
#  Last updated [yy/mm/dd]-LastUpdated
#  Right ascension [hh mm ss]-RightAscension
#  Declination [+/-dd mm ss]-Declination
#  Distance from Sun [parsec]-DistFromSunParsec
#  Host star mass [Solar masses]-HostStarMassSlrMass
#  Host star radius [Solar radii]-HostStarRadiusSlrRad
#  Host star metallicity [log relative to solar]-HostStarMetallicity
#  Host star temperature [K]-HostStarTempK
#  Host star age [Gyr]-HostStarAgeGyr
#  A list of lists the planet is -ListsPlanetIsOn

# %%
rows = part[1].split('\r\n')

# %%
dat_list = []
rows[0].split(',')
for row in rows:
    dat = {}
    for index,item in enumerate(row.split(',')):
        try:
            dat[column_list[index]] = item
        except:
            dat[column_list[-1]] += ', ' + item
    dat_list.append(dat)
dat_list[10]
# Out:
# {'AgeGyr': '',
#  'AscendingNodeDeg': '',
#  'Declination': '-30 22 38',
#  'DiscoveryMethod': 'microlensing',
#  'DiscoveryYear': '2005',
#  'DistFromSunParsec': '6500',
#  'Eccentricity': '',
#  'HostStarAgeGyr': '',
#  'HostStarMassSlrMass': '0.22',
#  'HostStarMetallicity': '',
#  'HostStarRadiusSlrRad': '',
#  'HostStarTempK': '3840.0',
#  'InclinationDeg': '',
#  'LastUpdated': '06/04/12',
#  'ListsPlanetIsOn': 'Confirmed planets',
#  'LongitudeDeg': '',
#  'PeriastronDeg': '',
#  'PeriodDays': '3500',
#  'PlanetIdentifier': 'OGLE-05-390L b',
#  'PlanetaryMassJpt': '0.017',
#  'RadiusJpt': '',
#  'RightAscension': '17 54 19',
#  'SemiMajorAxisAU': '2.1',
#  'SurfaceTempK': '',
#  'TypeFlag': '0'}

# %%
raw_df = pd.DataFrame(dat_list).set_index('PlanetIdentifier')
raw_df.tail(20)
# Out:
#                  AgeGyr AscendingNodeDeg     Declination DiscoveryMethod  \
# PlanetIdentifier
# Kepler-337 b                                   +47 09 50         transit
# GJ 536                                       -02 39 17.5              RV
# Kepler-1094 b                                  +38 16 01         transit
# Kepler-1142 b                                  +44 04 56         transit
# Kepler-823 b                                   +39 13 13         transit
# Kepler-582 b                                   +41 03 25         transit
# HD 222076                                      -70 05 48
# WASP-122 b                                   -42 24 35.1         transit
# FL Lyr b                                  +46 19 26.8632          timing
# HAT-P-21 b                                     +41 01 41         transit
# Kepler-1359 b                                  +41 53 34         transit
# HAT-P-67 b                                   +44 46 37.1
# HAT-P-34 b                                  +18 06 17.42         transit
# Kepler-658 b                                   +47 34 43         transit
# eta Cet b                                 -10 10 56.1570              RV
# eta Cet c                                 -10 10 56.1570              RV
# HD 108874 b                                    +22 52 47              RV
# HD 108874 c                                    +22 52 47              RV
# Kepler-1473 b                                  +48 59 46         transit
#                     NaN              NaN             NaN             NaN
#
#                  DiscoveryYear DistFromSunParsec Eccentricity HostStarAgeGyr  \
# PlanetIdentifier
# Kepler-337 b              2014            674.39
# GJ 536                    2016             10.03         0.08
# Kepler-1094 b             2016
# Kepler-1142 b             2016
# Kepler-823 b              2016
# Kepler-582 b              2016
# HD 222076                 2016              83.5         0.08
# WASP-122 b                2015                              0            5.0
# FL Lyr b                  2015               130
# HAT-P-21 b                2010               254        0.228
# Kepler-1359 b             2016
# HAT-P-67 b                2017             320.0         0.24           1.24
# HAT-P-34 b                2012               257        0.441
# Kepler-658 b              2016
# eta Cet b                 2014             37.99         0.17
# eta Cet c                 2014             37.99         0.02
# HD 108874 b               2003              68.5         0.07
# HD 108874 c               2005              68.5         0.25
# Kepler-1473 b             2016
#                            NaN               NaN          NaN            NaN
#
#                  HostStarMassSlrMass HostStarMetallicity   ...     \
# PlanetIdentifier                                           ...
# Kepler-337 b                  1.0210                       ...
# GJ 536                          0.52               -0.08   ...
# Kepler-1094 b                   1.14                0.06   ...
# Kepler-1142 b                   0.97                0.02   ...
# Kepler-823 b                    0.98                0.06   ...
# Kepler-582 b                    0.93                0.01   ...
# HD 222076                       1.07                0.05   ...
# WASP-122 b                       1.4                0.32   ...
# FL Lyr b                                                   ...
# HAT-P-21 b                     0.947                0.01   ...
# Kepler-1359 b                   0.78                0.11   ...
# HAT-P-67 b                     1.642               -0.08   ...
# HAT-P-34 b                     1.392                0.22   ...
# Kepler-658 b                    0.63               -0.04   ...
# eta Cet b                        1.7                0.12   ...
# eta Cet c                        1.7                0.12   ...
# HD 108874 b                        1                0.14   ...
# HD 108874 c                        1                0.14   ...
# Kepler-1473 b                   1.09               -0.01   ...
#                                  NaN                 NaN   ...
#
#                                                     ListsPlanetIsOn  \
# PlanetIdentifier
# Kepler-337 b                                      Confirmed planets
# GJ 536                                            Confirmed planets
# Kepler-1094 b                                     Confirmed planets
# Kepler-1142 b                                     Confirmed planets
# Kepler-823 b                                      Confirmed planets
# Kepler-582 b                                      Confirmed planets
# HD 222076                                         Confirmed planets
# WASP-122 b                                        Confirmed planets
# FL Lyr b          "Controversial,  Planets in binary systems,  P...
# HAT-P-21 b                                        Confirmed planets
# Kepler-1359 b                                     Confirmed planets
# HAT-P-67 b                                        Confirmed planets
# HAT-P-34 b                                        Confirmed planets
# Kepler-658 b                                      Confirmed planets
# eta Cet b                                         Confirmed planets
# eta Cet c                                         Confirmed planets
# HD 108874 b                                       Confirmed planets
# HD 108874 c                                       Confirmed planets
# Kepler-1473 b                                     Confirmed planets
#                                                                 NaN
#
#                  LongitudeDeg PeriastronDeg    PeriodDays PlanetaryMassJpt  \
# PlanetIdentifier
# Kepler-337 b                                     3.292781
# GJ 536                                288.7        8.7076           0.0169
# Kepler-1094 b                                78.100023100
# Kepler-1142 b                                18.302724800
# Kepler-823 b                                  4.168090820
# Kepler-582 b                                 18.492356680
# HD 222076                             241.0         871.0             1.56
# WASP-122 b                                      1.7100567            1.372
# FL Lyr b
# HAT-P-21 b                                       4.124461            4.063
# Kepler-1359 b                                59.497095200
# HAT-P-67 b                            172.0    4.81010205             0.34
# HAT-P-34 b                                         5.4527            3.328
# Kepler-658 b                                  1.287076760
# eta Cet b                             247.2         407.3             2.46
# eta Cet c                             36.67         744.3             3.16
# HD 108874 b                                         395.4             1.36
# HD 108874 c                                        1605.8            1.018
# Kepler-1473 b                                14.427355100
#                           NaN           NaN           NaN              NaN
#
#                  RadiusJpt  RightAscension SemiMajorAxisAU SurfaceTempK  \
# PlanetIdentifier
# Kepler-337 b       0.14034        19 20 14
# GJ 536                         14 01 03.19         0.06661
# Kepler-1094 b        0.284        19 29 12
# Kepler-1142 b        0.131        19 30 51
# Kepler-823 b         0.140        18 58 20
# Kepler-582 b         0.328        19 50 01
# HD 222076                         23 38 08            1.83
# WASP-122 b           1.972     07 13 12.34         0.03107         1960
# FL Lyr b                    19 12 04.86170
# HAT-P-21 b           1.024        11 25 06          0.0494       1161.5
# Kepler-1359 b        0.252        19 18 09
# HAT-P-67 b           2.085     17 06 26.56         0.06505
# HAT-P-34 b           1.197    20 12 46.885          0.0677       1335.3
# Kepler-658 b         0.145        18 51 56
# eta Cet b                   01 08 35.39148            1.27
# eta Cet c                   01 08 35.39148            1.93
# HD 108874 b                       12 30 26           1.051        256.8
# HD 108874 c                       12 30 26            2.68        160.2
# Kepler-1473 b        0.106        19 22 33
#                        NaN             NaN             NaN          NaN
#
#                  TypeFlag
# PlanetIdentifier
# Kepler-337 b            0
# GJ 536                  0
# Kepler-1094 b           0
# Kepler-1142 b           0
# Kepler-823 b            0
# Kepler-582 b            0
# HD 222076               0
# WASP-122 b              0
# FL Lyr b                1
# HAT-P-21 b              0
# Kepler-1359 b           0
# HAT-P-67 b              0
# HAT-P-34 b              0
# Kepler-658 b            0
# eta Cet b               0
# eta Cet c               0
# HD 108874 b             0
# HD 108874 c             0
# Kepler-1473 b           0
#                       NaN
#
# [20 rows x 24 columns]

# %% [markdown]
# ### Kepler-953 b&c have duplicates as found in the host star loop so they are cleaned below

# %%
raw_df.loc['Kepler-953 c']
# Out:
#                  AgeGyr AscendingNodeDeg Declination DiscoveryMethod  \
# PlanetIdentifier
# Kepler-953 c                               +44 37 28         transit
# Kepler-953 c                               +44 37 28         transit
#
#                  DiscoveryYear DistFromSunParsec Eccentricity HostStarAgeGyr  \
# PlanetIdentifier
# Kepler-953 c              2016
# Kepler-953 c              2016
#
#                  HostStarMassSlrMass HostStarMetallicity   ...     \
# PlanetIdentifier                                           ...
# Kepler-953 c                    0.94               0.015   ...
# Kepler-953 c                    0.95                0.26   ...
#
#                     ListsPlanetIsOn LongitudeDeg PeriastronDeg   PeriodDays  \
# PlanetIdentifier
# Kepler-953 c      Confirmed planets                              9.10967112
# Kepler-953 c      Confirmed planets                             9.109671120
#
#                  PlanetaryMassJpt RadiusJpt RightAscension SemiMajorAxisAU  \
# PlanetIdentifier
# Kepler-953 c                          0.106       19 15 53
# Kepler-953 c                          0.106       19 15 53
#
#                  SurfaceTempK TypeFlag
# PlanetIdentifier
# Kepler-953 c                         0
# Kepler-953 c                         0
#
# [2 rows x 24 columns]

# %%
#columns_to_copy = ['SemiMajorAxisAU','InclinationDeg']
new_keplerc_row = raw_df.loc['Kepler-953 c'].iloc[1] #the first is for some other planet
new_keplerc_row
# Out:
# AgeGyr
# AscendingNodeDeg
# Declination                     +44 37 28
# DiscoveryMethod                   transit
# DiscoveryYear                        2016
# DistFromSunParsec
# Eccentricity
# HostStarAgeGyr
# HostStarMassSlrMass                  0.95
# HostStarMetallicity                  0.26
# HostStarRadiusSlrRad                 0.99
# HostStarTempK                      5416.0
# InclinationDeg
# LastUpdated                      16/05/10
# ListsPlanetIsOn         Confirmed planets
# LongitudeDeg
# PeriastronDeg
# PeriodDays                    9.109671120
# PlanetaryMassJpt
# RadiusJpt                           0.106
# RightAscension                   19 15 53
# SemiMajorAxisAU
# SurfaceTempK
# TypeFlag                                0
# Name: Kepler-953 c, dtype: object

# %%
columns_to_copy = ['SemiMajorAxisAU','InclinationDeg']
new_keplerb_row = raw_df.loc['Kepler-953 b'].iloc[1] #the first is for some other planet
for column in columns_to_copy:
    new_keplerb_row[column] = raw_df.loc['Kepler-953 b'].iloc[0][column]
new_keplerb_row
# Out:
# AgeGyr
# AscendingNodeDeg
# Declination                     +44 37 28
# DiscoveryMethod                   transit
# DiscoveryYear                        2016
# DistFromSunParsec
# Eccentricity
# HostStarAgeGyr
# HostStarMassSlrMass                  0.95
# HostStarMetallicity                  0.26
# HostStarRadiusSlrRad                 0.99
# HostStarTempK                      5416.0
# InclinationDeg                      89.53
# LastUpdated                      16/05/10
# ListsPlanetIsOn         Confirmed planets
# LongitudeDeg
# PeriastronDeg
# PeriodDays                   88.406552580
# PlanetaryMassJpt
# RadiusJpt                           0.376
# RightAscension                   19 15 53
# SemiMajorAxisAU                   0.19757
# SurfaceTempK
# TypeFlag                                0
# Name: Kepler-953 b, dtype: object

# %%
df = raw_df.drop('Kepler-953 b').drop('Kepler-953 c')
df.loc['Kepler-953 b'] = new_keplerb_row
df.loc['Kepler-953 c'] = new_keplerc_row

df = df.dropna(how='all') # get rid of bottom allnan row

df.tail()
# Out:
#                  AgeGyr AscendingNodeDeg Declination DiscoveryMethod  \
# PlanetIdentifier
# HD 108874 b                                +22 52 47              RV
# HD 108874 c                                +22 52 47              RV
# Kepler-1473 b                              +48 59 46         transit
# Kepler-953 b                               +44 37 28         transit
# Kepler-953 c                               +44 37 28         transit
#
#                  DiscoveryYear DistFromSunParsec Eccentricity HostStarAgeGyr  \
# PlanetIdentifier
# HD 108874 b               2003              68.5         0.07
# HD 108874 c               2005              68.5         0.25
# Kepler-1473 b             2016
# Kepler-953 b              2016
# Kepler-953 c              2016
#
#                  HostStarMassSlrMass HostStarMetallicity   ...     \
# PlanetIdentifier                                           ...
# HD 108874 b                        1                0.14   ...
# HD 108874 c                        1                0.14   ...
# Kepler-1473 b                   1.09               -0.01   ...
# Kepler-953 b                    0.95                0.26   ...
# Kepler-953 c                    0.95                0.26   ...
#
#                     ListsPlanetIsOn LongitudeDeg PeriastronDeg    PeriodDays  \
# PlanetIdentifier
# HD 108874 b       Confirmed planets                                    395.4
# HD 108874 c       Confirmed planets                                   1605.8
# Kepler-1473 b     Confirmed planets                             14.427355100
# Kepler-953 b      Confirmed planets                             88.406552580
# Kepler-953 c      Confirmed planets                              9.109671120
#
#                  PlanetaryMassJpt RadiusJpt RightAscension SemiMajorAxisAU  \
# PlanetIdentifier
# HD 108874 b                  1.36                 12 30 26           1.051
# HD 108874 c                 1.018                 12 30 26            2.68
# Kepler-1473 b                         0.106       19 22 33
# Kepler-953 b                          0.376       19 15 53         0.19757
# Kepler-953 c                          0.106       19 15 53
#
#                  SurfaceTempK TypeFlag
# PlanetIdentifier
# HD 108874 b             256.8        0
# HD 108874 c             160.2        0
# Kepler-1473 b                        0
# Kepler-953 b                         0
# Kepler-953 c                         0
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Add HostStar Column
# 3 basic types of planet name declarations
# 1. "HostStar letter"
# 2. "HostStar.num"
# 3. "Planet"
# filtered below to pull host star

# %%
#df.loc['Earth']
#filtering for star column
planets = df.index.values.tolist() #filtering this way reveals duplicates

our_planets = [
    'Mercury',
    'Venus',
    'Earth',
    'Mars',
    'Jupiter',
    'Saturn',
    'Uranus',
    'Neptune',
    'Pluto'
]
sun_column = []
sun_list = []

for index,planet in enumerate(planets):
    #ensure index is right
    #print(df.loc[planet,'PlanetaryMassJpt'])
    #print(df.iloc[index, 1])
    try:
        if df.loc[planet,'TypeFlag'] == 3:
            # TypeFlag 3 means lone planet without sun, could be none but would inhibit group_by
            sun = planet
        elif planet in our_planets:
            sun = 'sun'
        elif planet[-2] == ' ':
            sun = planet[:-2]
        elif planet[-3] == '.':
            sun = planet[:-3]
        else:
            print(df.loc[planet,'TypeFlag'], ' - ', planet) #shouldn't list any 3s but does
            sun = planet
        
        sun_column.append(sun)
        if sun not in sun_list:
            sun_list.append(sun)
            
    except IndexError:
        print(df.loc[planet])
    #print(planet)

print(index)
#print(sun_column)
# Out:
# 0  -  Kepler-91 b Trojan
# 0  -  SDSS J1110+0116
# 2  -  TrES-2
# 0  -  SIMP0136+0933
# 3  -  PSO J318.5-22
# 3  -  CFBDSIR2149
# 0  -  OGLE-2014-BLG-0676L
# 1  -  HD 131399 Ab
# 0  -  SWEEPS-11
# 0  -  KOI-72.X
# 0  -  HD 86950
# 0  -  HD 220842
# 0  -  OGLE-2013-BLG-0102LB
# 0  -  EPIC 220504338
# 0  -  MOA-2011-BLG-262Lb
# 3  -  WISE 0855-0714
# 0  -  2MASS J21265040-8140293
# 0  -  SWEEPS-4
# 0  -  Lupus-TR 3b
# 0  -  HIP 65426
# 0  -  GJ 536
# 0  -  HD 222076
# 3656

# %%
df['HostStar'] = sun_column
#check that the HostStar column lines up
df.head()
# Out:
#                  AgeGyr AscendingNodeDeg  Declination DiscoveryMethod  \
# PlanetIdentifier
# KOI-1843.03                               +40 13 14.7         transit
# Kepler-974 b                              +40 13 14.7         transit
# KOI-1843.02                               +40 13 14.7         transit
# Kepler-9 b                                  +38 24 03         transit
# Kepler-9 c                                  +38 24 03         transit
#
#                  DiscoveryYear DistFromSunParsec Eccentricity HostStarAgeGyr  \
# PlanetIdentifier
# KOI-1843.03               2012
# Kepler-974 b
# KOI-1843.02
# Kepler-9 b                2010               650       0.0626
# Kepler-9 c                2010               650       0.0684
#
#                  HostStarMassSlrMass HostStarMetallicity     ...      \
# PlanetIdentifier                                             ...
# KOI-1843.03                     0.52                0.07     ...
# Kepler-974 b                    0.52                0.07     ...
# KOI-1843.02                     0.52                0.07     ...
# Kepler-9 b                      1.07                0.12     ...
# Kepler-9 c                      1.07                0.12     ...
#
#                  LongitudeDeg PeriastronDeg   PeriodDays PlanetaryMassJpt  \
# PlanetIdentifier
# KOI-1843.03                                    0.1768913           0.0014
# Kepler-974 b                                 4.194496510
# KOI-1843.02                                     6.356006
# Kepler-9 b                                      19.22418             0.25
# Kepler-9 c                                      39.03106             0.17
#
#                  RadiusJpt RightAscension SemiMajorAxisAU SurfaceTempK  \
# PlanetIdentifier
# KOI-1843.03          0.054    19 00 03.14          0.0048
# Kepler-974 b         0.140    19 00 03.14           0.039
# KOI-1843.02          0.071    19 00 03.14           0.052
# Kepler-9 b            0.84       19 02 17           0.143        707.2
# Kepler-9 c            0.82       19 02 17           0.229        557.9
#
#                  TypeFlag    HostStar
# PlanetIdentifier
# KOI-1843.03             0    KOI-1843
# Kepler-974 b            0  Kepler-974
# KOI-1843.02             0    KOI-1843
# Kepler-9 b              0    Kepler-9
# Kepler-9 c              0    Kepler-9
#
# [5 rows x 25 columns]

# %% [markdown]
# ### add Luminosity column to calculate Habitable Zone
# L ≈ 4π*(R^2)*σ*(T^4)
#
# Luminosity in Watts?
# solar Radius in Meters?
# solar Temperature in Kelvin
# σ = Stefan-Boltzmann constant = 5.67 × 10^-8 W m^-2 K^-4
#
# solarRadius = 6.95700×10^8 meters
# AU = 149597900000 meters
#
# http://www.atnf.csiro.au/outreach/education/senior/astrophysics/photometry_luminosity.html

# %%
AU = 149597900000 #meters
SR = 6.95700*(10**8) #meters
boltzmann = 5.67*(10**(-8)) # W m^-2 K^-4

# %%
#using our sun as a sample
sun_temp = 5772.0
sun_radius = SR

# %%
def lumCalc(radiusSR, temp):
    AU = 149597900000 #meters
    SR = 6.95700*(10**8) #meters
    boltzmann = 5.67*(10**(-8)) # W m^-2 K^-4 
    radius = radiusSR*SR
    lum = 4 * 3.14 * (radius**2) * boltzmann * (temp**4)
    return lum
lumCalc(1,sun_temp) #came out to the real value of 3.8e26
# Out:
# 3.825797637984441e+26

# %%
radii = df.HostStarRadiusSlrRad.values.tolist() #filtering this way reveals duplicates
temps = df.HostStarTempK.values.tolist()
lums = []

for index, radius in enumerate(radii):
    #print(radius, ' - ', temps[index])
    try:
        lums.append(lumCalc(float(radius), float(temps[index])))
    except ValueError:
        lums.append('nan')
        

df['HostStarLuminosity'] = lums

# %% [markdown]
# ### Calculating Habitable zones from Luminosity and Mass
#
#
# http://www.planetarybiology.com/calculating_habitable_zone.html

# %%
def Habitable_Zones(lum):
    sun_lum = lumCalc(1,sun_temp)
    Ri = ((lum/sun_lum)/1.1)**.5
    Ro = ((lum/sun_lum)/.53)**.5
    return (Ri,Ro)

# %%
inner_habs = []
outer_habs = []
for lum in lums:
    try:
        (Ri,Ro) = Habitable_Zones(lum)
    except TypeError:
        (Ri, Ro) = ('nan','nan')
    inner_habs.append(Ri)
    outer_habs.append(Ro)
    
df['HostStarInnerHabitabilityAU'] = inner_habs
df['HostStarOuterHabitabilityAU'] = outer_habs
outer_habs
# Out:
# [0.2802371450504052,
#  1.4298380468738905,
#  1.4298380468738905,
#  0.8060998906524072,
#  1.5968869138520467,
#  0.9507504222801286,
#  0.9011980747409936,
#  2.314148126097648,
#  2.314148126097648,
#  2.314148126097648,
#  2.314148126097648,
#  2.578322003843927,
#  0.9194255487324975,
#  1.28889916718863,
#  0.8702513762490259,
#  3.044229923081475,
#  2.535168052235701,
#  0.8152297899098624,
#  0.8152297899098624,
#  0.8093025092339807,
#  0.09125890871754408,
#  1.0937585918637875,
#  0.9213740927166251,
#  0.9213740927166251,
#  1.7067087127814597,
#  3.2291162601326295,
#  1.8686014044956964,
#  1.8686014044956964,
#  0.8142851605363384,
#  0.6164500352175059,
#  0.5738039394519816,
#  1.7023578985250132,
#  1.992320771405623,
#  1.992320771405623,
#  3.545351667415126,
#  3.545351667415126,
#  1.6805488958544574,
#  0.08263034111814876,
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  2.012424515615576,
#  2.012424515615576,
#  'nan',
#  1.4567904746282483,
#  3.4383104568805054,
#  2.493868894208812,
#  'nan',
#  1.2658135590831474,
#  1.9662286086293579,
#  1.40375443417427,
#  ...]

# %% [markdown]
# ### Classifying Suns

# %%
stellar_classes = []
stellar_colors =[]
temp = .5
def calculateBS(temp):
    if 2400 < temp and temp < 3700:
        stellar_class = 'M'
        BC = -2.0
        color = '#ffcc6f'
    elif 3700 < temp and temp < 5200:
        stellar_class = 'K'
        BC = -0.8
        color = '#ffd2a1'
    elif 5200 < temp and temp < 6000:
        stellar_class = 'G'
        BC = -.4
        color = '#fff4ea'
    elif 6000 < temp and temp < 7500:
        stellar_class = 'F'
        BC = -.15
        color = '#f8f7ff'
    elif 7500 < temp and temp < 10000:
        stellar_class = 'A'
        BC = -.3
        color = '#cad7ff'
    elif 10000 < temp and temp < 30000:
        stellar_class = 'B'
        BC = -2.0
        color = '#aabfff'
    elif 30000 < temp:
        stellar_class = 'O'
        BC = 'nan'
        color = '#9bb0ff'
    else:
        return ('nan','nan')
    return (stellar_class, color, BC)

for index,temp in enumerate(df.HostStarTempK.values.tolist()):
    #type flag lists special circumstances of sun, 0 is an 'ordinary' singular sun
    #print(df.TypeFlag.iloc[index])
    if int(df.TypeFlag.iloc[index]) == 1:
        stellar_classes.append("P-type binary")
        stellar_colors.append('nan')
    elif int(df.TypeFlag.iloc[index]) == 2:
        stellar_classes.append("S-type binary")
        stellar_colors.append('nan')
    elif int(df.TypeFlag.iloc[index]) == 3:
        stellar_classes.append("nan") #is a lone planet
        stellar_colors.append('nan')
    elif int(df.TypeFlag.iloc[index]) == 0:
        try:
            (cla, col, bc) = calculateBS(float(temp))
            stellar_classes.append(cla)
            stellar_colors.append(col)
        except ValueError:
            stellar_classes.append('nan')
            stellar_colors.append('nan')


df['HostStarClass'] = stellar_classes
df['HostStarColor'] = stellar_colors

# %% [markdown]
# ### Drop columns that don't seem useful now, can always be added back

# %%
drop_columns = ['LongitudeDeg', 'AscendingNodeDeg', 'InclinationDeg','HostStarAgeGyr','Declination','DistFromSunParsec','RightAscension','LastUpdated','AgeGyr','PeriastronDeg']
final_df = df.drop(drop_columns, axis = 1)

# %%
final_df.head()
# Out:
#                  DiscoveryMethod DiscoveryYear Eccentricity  \
# PlanetIdentifier
# KOI-1843.03              transit          2012
# Kepler-974 b             transit
# KOI-1843.02              transit
# Kepler-9 b               transit          2010       0.0626
# Kepler-9 c               transit          2010       0.0684
#
#                  HostStarMassSlrMass HostStarMetallicity HostStarRadiusSlrRad  \
# PlanetIdentifier
# KOI-1843.03                     0.52                0.07                 0.50
# Kepler-974 b                    0.52                0.07                 0.50
# KOI-1843.02                     0.52                0.07                 0.50
# Kepler-9 b                      1.07                0.12                 1.02
# Kepler-9 c                      1.07                0.12                 1.02
#
#                  HostStarTempK    ListsPlanetIsOn   PeriodDays  \
# PlanetIdentifier
# KOI-1843.03             3687.0      Controversial    0.1768913
# Kepler-974 b            3687.0  Confirmed planets  4.194496510
# KOI-1843.02             3687.0      Controversial     6.356006
# Kepler-9 b                5777  Confirmed planets     19.22418
# Kepler-9 c                5777  Confirmed planets     39.03106
#
#                  PlanetaryMassJpt RadiusJpt SemiMajorAxisAU SurfaceTempK  \
# PlanetIdentifier
# KOI-1843.03                0.0014     0.054          0.0048
# Kepler-974 b                          0.140           0.039
# KOI-1843.02                           0.071           0.052
# Kepler-9 b                   0.25      0.84           0.143        707.2
# Kepler-9 c                   0.17      0.82           0.229        557.9
#
#                  TypeFlag    HostStar HostStarLuminosity  \
# PlanetIdentifier
# KOI-1843.03             0    KOI-1843        1.59239e+25
# Kepler-974 b            0  Kepler-974        1.59239e+25
# KOI-1843.02             0    KOI-1843        1.59239e+25
# Kepler-9 b              0    Kepler-9        3.99417e+26
# Kepler-9 c              0    Kepler-9        3.99417e+26
#
#                  HostStarInnerHabitabilityAU HostStarOuterHabitabilityAU  \
# PlanetIdentifier
# KOI-1843.03                         0.194521                    0.280237
# Kepler-974 b                        0.194521                    0.280237
# KOI-1843.02                         0.194521                    0.280237
# Kepler-9 b                          0.974217                     1.40351
# Kepler-9 c                          0.974217                     1.40351
#
#                  HostStarClass HostStarColor
# PlanetIdentifier
# KOI-1843.03                  M       #ffcc6f
# Kepler-974 b                 M       #ffcc6f
# KOI-1843.02                  M       #ffcc6f
# Kepler-9 b                   G       #fff4ea
# Kepler-9 c                   G       #fff4ea

# %% [markdown]
# ### Write to csv

# %%
final_df.to_csv('cleaned_data.csv')

# %%
final_df
# Out:
#                   DiscoveryMethod DiscoveryYear Eccentricity  \
# PlanetIdentifier
# KOI-1843.03               transit          2012
# Kepler-974 b              transit
# KOI-1843.02               transit
# Kepler-9 b                transit          2010       0.0626
# Kepler-9 c                transit          2010       0.0684
# Kepler-9 d                transit          2010
# GJ 160.2 b                     RV          2014         0.06
# Kepler-566 b              transit          2016
# WASP-124 b                transit          2016
# HD 240210 b                    RV          2009         0.15
# OGLE-05-390L b       microlensing          2005
# Kepler-1343 b             transit          2016
# Kepler-1011 b             transit          2016
# WASP-82 b                 transit          2013
# Gliese 1214 b             transit          2009            0
# CoRoT-30 b                transit          2017        0.007
# Kepler-153 b              transit          2014
# Kepler-153 c              transit          2014
# HD 4203 b                      RV          2001         0.52
# HD 4203 c                      RV          2014        0.182
# HD 179079 b                    RV          2009        0.115
# Kepler-1368 b             transit          2016
# HD 187123 b                    RV          1998       0.0093
# HD 187123 c                    RV          2007        0.295
# Kepler-1111 b             transit          2016
# Kepler-1289 b             transit          2016
# KIC 5095269(AB) b                          2017       0.0604
# Kepler-431 b              transit          2015
# Kepler-431 c              transit          2015
# Kepler-431 d              transit          2015
# ...                           ...           ...          ...
# Kepler-1018 b             transit          2016
# CoRoT-8 b                 transit          2010          0.0
# Kepler-1627 b             transit          2016
# Kepler-729 b              transit          2016
# KOI-89 b                  transit          2011
# KOI-89.02                 transit          2011
# Kepler-312 c              transit          2014
# Kepler-312 b              transit          2014
# Kepler-337 c              transit          2014
# Kepler-337 b              transit          2014
# GJ 536                         RV          2016         0.08
# Kepler-1094 b             transit          2016
# Kepler-1142 b             transit          2016
# Kepler-823 b              transit          2016
# Kepler-582 b              transit          2016
# HD 222076                                  2016         0.08
# WASP-122 b                transit          2015            0
# FL Lyr b                   timing          2015
# HAT-P-21 b                transit          2010        0.228
# Kepler-1359 b             transit          2016
# HAT-P-67 b                                 2017         0.24
# HAT-P-34 b                transit          2012        0.441
# Kepler-658 b              transit          2016
# eta Cet b                      RV          2014         0.17
# eta Cet c                      RV          2014         0.02
# HD 108874 b                    RV          2003         0.07
# HD 108874 c                    RV          2005         0.25
# Kepler-1473 b             transit          2016
# Kepler-953 b              transit          2016
# Kepler-953 c              transit          2016
#
#                   HostStarMassSlrMass HostStarMetallicity  \
# PlanetIdentifier
# KOI-1843.03                      0.52                0.07
# Kepler-974 b                     0.52                0.07
# KOI-1843.02                      0.52                0.07
# Kepler-9 b                       1.07                0.12
# Kepler-9 c                       1.07                0.12
# Kepler-9 d                       1.07                0.12
# GJ 160.2 b                       0.69
# Kepler-566 b                     0.83               -0.01
# WASP-124 b                       1.07               -0.02
# HD 240210 b                      0.82               -0.18
# OGLE-05-390L b                   0.22
# Kepler-1343 b                    0.95               -0.16
# Kepler-1011 b                    0.91                0.08
# WASP-82 b                        1.63                0.12
# Gliese 1214 b                   0.176                 0.1
# CoRoT-30 b                       0.97                0.02
# Kepler-153 b                   0.8200
# Kepler-153 c                   0.8200
# HD 4203 b                       1.130               0.453
# HD 4203 c                       1.130               0.453
# HD 179079 b                     1.087                0.29
# Kepler-1368 b                    1.07                0.10
# HD 187123 b                     1.037               0.121
# HD 187123 c                     1.037               0.121
# Kepler-1111 b                    1.10                0.02
# Kepler-1289 b                    1.10                0.02
# KIC 5095269(AB) b
# Kepler-431 b                    1.071
# Kepler-431 c                    1.071
# Kepler-431 d                    1.071
# ...                               ...                 ...
# Kepler-1018 b                    0.91               -0.05
# CoRoT-8 b                        0.88                 0.3
# Kepler-1627 b                    0.87               -0.10
# Kepler-729 b                     0.94               -0.05
# KOI-89 b                         1.59               -0.06
# KOI-89.02                        1.59               -0.06
# Kepler-312 c
# Kepler-312 b
# Kepler-337 c                   1.0210
# Kepler-337 b                   1.0210
# GJ 536                           0.52               -0.08
# Kepler-1094 b                    1.14                0.06
# Kepler-1142 b                    0.97                0.02
# Kepler-823 b                     0.98                0.06
# Kepler-582 b                     0.93                0.01
# HD 222076                        1.07                0.05
# WASP-122 b                        1.4                0.32
# FL Lyr b
# HAT-P-21 b                      0.947                0.01
# Kepler-1359 b                    0.78                0.11
# HAT-P-67 b                      1.642               -0.08
# HAT-P-34 b                      1.392                0.22
# Kepler-658 b                     0.63               -0.04
# eta Cet b                         1.7                0.12
# eta Cet c                         1.7                0.12
# HD 108874 b                         1                0.14
# HD 108874 c                         1                0.14
# Kepler-1473 b                    1.09               -0.01
# Kepler-953 b                     0.95                0.26
# Kepler-953 c                     0.95                0.26
#
#                   HostStarRadiusSlrRad HostStarTempK  \
# PlanetIdentifier
# KOI-1843.03                       0.50        3687.0
# Kepler-974 b                      0.50        3687.0
# KOI-1843.02                       0.50        3687.0
# Kepler-9 b                        1.02          5777
# Kepler-9 c                        1.02          5777
# Kepler-9 d                        1.02          5777
# GJ 160.2 b                                      4347
# Kepler-566 b                      0.79        5132.0
# WASP-124 b                                      6050
# HD 240210 b                                     4297
# OGLE-05-390L b                                3840.0
# Kepler-1343 b                     0.93        5759.0
# Kepler-1011 b                     0.88        5416.0
# WASP-82 b                         2.18          6490
# Gliese 1214 b                   0.2213          3250
# CoRoT-30 b                        0.92        5650.0
# Kepler-153 b                     0.892          5404
# Kepler-153 c                     0.892          5404
# HD 4203 b                         1.33          5702
# HD 4203 c                         1.33          5702
# HD 179079 b                       1.48        5724.0
# Kepler-1368 b                     1.08        5906.0
# HD 187123 b                      1.143          5815
# HD 187123 c                      1.143          5815
# Kepler-1111 b                     1.15        6077.0
# Kepler-1289 b                     1.17        6080.0
# KIC 5095269(AB) b
# Kepler-431 b                     1.092          6004
# Kepler-431 c                     1.092          6004
# Kepler-431 d                     1.092          6004
# ...                                ...           ...
# Kepler-1018 b                     0.88        5518.0
# CoRoT-8 b                         0.77        5080.0
# Kepler-1627 b                     0.84        5445.0
# Kepler-729 b                      0.91        5633.0
# KOI-89 b                          2.04        7070.0
# KOI-89.02                         2.04        7070.0
# Kepler-312 c                     1.467          6115
# Kepler-312 b                     1.467          6115
# Kepler-337 c                     1.761          5684
# Kepler-337 b                     1.761          5684
# GJ 536                             0.5        3685.0
# Kepler-1094 b                     1.21        6112.0
# Kepler-1142 b                     0.96        5685.0
# Kepler-823 b                      0.96        5643.0
# Kepler-582 b                      0.91        5564.0
# HD 222076                         4.14        4806.0
# WASP-122 b                       1.567          5720
# FL Lyr b
# HAT-P-21 b                       1.105        5588.0
# Kepler-1359 b                     0.72        4709.0
# HAT-P-67 b                       1.546        6406.0
# HAT-P-34 b                       1.535        6442.0
# Kepler-658 b                      0.60        4103.0
# eta Cet b                         14.3          4528
# eta Cet c                         14.3          4528
# HD 108874 b                       1.22        5407.0
# HD 108874 c                       1.22        5407.0
# Kepler-1473 b                     1.09        6046.0
# Kepler-953 b                      0.99        5416.0
# Kepler-953 c                      0.99        5416.0
#
#                                                      ListsPlanetIsOn  \
# PlanetIdentifier
# KOI-1843.03                                            Controversial
# Kepler-974 b                                       Confirmed planets
# KOI-1843.02                                            Controversial
# Kepler-9 b                                         Confirmed planets
# Kepler-9 c                                         Confirmed planets
# Kepler-9 d                                         Confirmed planets
# GJ 160.2 b                                             Controversial
# Kepler-566 b                                       Confirmed planets
# WASP-124 b                                         Confirmed planets
# HD 240210 b                                        Confirmed planets
# OGLE-05-390L b                                     Confirmed planets
# Kepler-1343 b                                      Confirmed planets
# Kepler-1011 b                                      Confirmed planets
# WASP-82 b                                          Confirmed planets
# Gliese 1214 b                                      Confirmed planets
# CoRoT-30 b                                         Confirmed planets
# Kepler-153 b                                       Confirmed planets
# Kepler-153 c                                       Confirmed planets
# HD 4203 b                                          Confirmed planets
# HD 4203 c                                          Confirmed planets
# HD 179079 b                                        Confirmed planets
# Kepler-1368 b                                      Confirmed planets
# HD 187123 b                                        Confirmed planets
# HD 187123 c                                        Confirmed planets
# Kepler-1111 b                                      Confirmed planets
# Kepler-1289 b                                      Confirmed planets
# KIC 5095269(AB) b                                  Confirmed planets
# Kepler-431 b                                       Confirmed planets
# Kepler-431 c                                       Confirmed planets
# Kepler-431 d                                       Confirmed planets
# ...                                                              ...
# Kepler-1018 b                                      Confirmed planets
# CoRoT-8 b                                          Confirmed planets
# Kepler-1627 b                                      Confirmed planets
# Kepler-729 b                                       Confirmed planets
# KOI-89 b                                           Confirmed planets
# KOI-89.02                                          Confirmed planets
# Kepler-312 c                                       Confirmed planets
# Kepler-312 b                                       Confirmed planets
# Kepler-337 c                                       Confirmed planets
# Kepler-337 b                                       Confirmed planets
# GJ 536                                             Confirmed planets
# Kepler-1094 b                                      Confirmed planets
# Kepler-1142 b                                      Confirmed planets
# Kepler-823 b                                       Confirmed planets
# Kepler-582 b                                       Confirmed planets
# HD 222076                                          Confirmed planets
# WASP-122 b                                         Confirmed planets
# FL Lyr b           "Controversial,  Planets in binary systems,  P...
# HAT-P-21 b                                         Confirmed planets
# Kepler-1359 b                                      Confirmed planets
# HAT-P-67 b                                         Confirmed planets
# HAT-P-34 b                                         Confirmed planets
# Kepler-658 b                                       Confirmed planets
# eta Cet b                                          Confirmed planets
# eta Cet c                                          Confirmed planets
# HD 108874 b                                        Confirmed planets
# HD 108874 c                                        Confirmed planets
# Kepler-1473 b                                      Confirmed planets
# Kepler-953 b                                       Confirmed planets
# Kepler-953 c                                       Confirmed planets
#
#                      PeriodDays PlanetaryMassJpt RadiusJpt SemiMajorAxisAU  \
# PlanetIdentifier
# KOI-1843.03           0.1768913           0.0014     0.054          0.0048
# Kepler-974 b        4.194496510                      0.140           0.039
# KOI-1843.02            6.356006                      0.071           0.052
# Kepler-9 b             19.22418             0.25      0.84           0.143
# Kepler-9 c             39.03106             0.17      0.82           0.229
# Kepler-9 d             1.592851            0.022     0.147          0.0271
# GJ 160.2 b               5.2354           0.0321                     0.053
# Kepler-566 b       18.427946240                      0.192
# WASP-124 b             3.372650              0.6      1.24          0.0449
# HD 240210 b              501.75             5.21                      1.33
# OGLE-05-390L b             3500            0.017                       2.1
# Kepler-1343 b       3.351831580                      0.172
# Kepler-1011 b       5.753221970                      0.256
# WASP-82 b              2.705782             1.24      1.67          0.0447
# Gliese 1214 b        1.58040417           0.0195    0.2525         0.01488
# CoRoT-30 b              9.06005             2.84      1.02           0.084
# Kepler-153 b          18.870227                    0.26610
# Kepler-153 c          46.902320                    0.23056
# HD 4203 b                437.05             1.82                    1.1735
# HD 4203 c                  7053             1.51                      7.50
# HD 179079 b              14.476             0.08                      0.11
# Kepler-1368 b       0.675649490                      0.147
# HD 187123 b           3.0965886           0.5074                   0.04213
# HD 187123 c                3380             1.80                      4.46
# Kepler-1111 b       8.796178630                      0.178
# Kepler-1289 b       7.990196270                      0.136
# KIC 5095269(AB) b     237.70817            7.698
# Kepler-431 b              6.803                     0.0682          0.0719
# Kepler-431 c              8.703                     0.0596          0.0847
# Kepler-431 d             11.922                     0.0990          0.1045
# ...                         ...              ...       ...             ...
# Kepler-1018 b      49.101351400                      0.230
# CoRoT-8 b               6.21229             0.22      0.57           0.063
# Kepler-1627 b       7.202836530                      0.329
# Kepler-729 b        3.166353710                      0.319
# KOI-89 b           84.687980800                      0.336
# KOI-89.02                207.58                       0.43
# Kepler-312 c          19.747412                    0.28706
# Kepler-312 b           1.772419                    0.11756
# Kepler-337 c           9.693201                    0.18682
# Kepler-337 b           3.292781                    0.14034
# GJ 536                   8.7076           0.0169                   0.06661
# Kepler-1094 b      78.100023100                      0.284
# Kepler-1142 b      18.302724800                      0.131
# Kepler-823 b        4.168090820                      0.140
# Kepler-582 b       18.492356680                      0.328
# HD 222076                 871.0             1.56                      1.83
# WASP-122 b            1.7100567            1.372     1.972         0.03107
# FL Lyr b
# HAT-P-21 b             4.124461            4.063     1.024          0.0494
# Kepler-1359 b      59.497095200                      0.252
# HAT-P-67 b           4.81010205             0.34     2.085         0.06505
# HAT-P-34 b               5.4527            3.328     1.197          0.0677
# Kepler-658 b        1.287076760                      0.145
# eta Cet b                 407.3             2.46                      1.27
# eta Cet c                 744.3             3.16                      1.93
# HD 108874 b               395.4             1.36                     1.051
# HD 108874 c              1605.8            1.018                      2.68
# Kepler-1473 b      14.427355100                      0.106
# Kepler-953 b       88.406552580                      0.376         0.19757
# Kepler-953 c        9.109671120                      0.106
#
#                   SurfaceTempK TypeFlag         HostStar HostStarLuminosity  \
# PlanetIdentifier
# KOI-1843.03                           0         KOI-1843        1.59239e+25
# Kepler-974 b                          0       Kepler-974        1.59239e+25
# KOI-1843.02                           0         KOI-1843        1.59239e+25
# Kepler-9 b               707.2        0         Kepler-9        3.99417e+26
# Kepler-9 c               557.9        0         Kepler-9        3.99417e+26
# Kepler-9 d              1601.5        0         Kepler-9        3.99417e+26
# GJ 160.2 b                            0         GJ 160.2                nan
# Kepler-566 b                          0       Kepler-566        1.49217e+26
# WASP-124 b                1400        0         WASP-124                nan
# HD 240210 b                           0        HD 240210                nan
# OGLE-05-390L b                        0     OGLE-05-390L                nan
# Kepler-1343 b                         0      Kepler-1343        3.27922e+26
# Kepler-1011 b                         0      Kepler-1011        2.29666e+26
# WASP-82 b                 2190        0          WASP-82        2.90609e+27
# Gliese 1214 b              604        0      Gliese 1214        1.88327e+24
# CoRoT-30 b                            0         CoRoT-30        2.97294e+26
# Kepler-153 b                          0       Kepler-153        2.33888e+26
# Kepler-153 c                          0       Kepler-153        2.33888e+26
# HD 4203 b                             0          HD 4203        6.44509e+26
# HD 4203 c                             0          HD 4203        6.44509e+26
# HD 179079 b              925.0        0        HD 179079        8.10473e+26
# Kepler-1368 b                         0      Kepler-1368        4.89145e+26
# HD 187123 b                           0        HD 187123        5.14882e+26
# HD 187123 c                           0        HD 187123        5.14882e+26
# Kepler-1111 b                         0      Kepler-1111        6.21683e+26
# Kepler-1289 b                         0      Kepler-1289        6.44767e+26
# KIC 5095269(AB) b                     0  KIC 5095269(AB)                nan
# Kepler-431 b                          0       Kepler-431        5.34103e+26
# Kepler-431 c                          0       Kepler-431        5.34103e+26
# Kepler-431 d                          0       Kepler-431        5.34103e+26
# ...                        ...      ...              ...                ...
# Kepler-1018 b                         0      Kepler-1018        2.47462e+26
# CoRoT-8 b                783.1        0          CoRoT-8        1.36098e+26
# Kepler-1627 b                         0      Kepler-1627         2.1378e+26
# Kepler-729 b                          0       Kepler-729        2.87381e+26
# KOI-89 b                              0           KOI-89        3.58389e+27
# KOI-89.02                             0           KOI-89        3.58389e+27
# Kepler-312 c                          0       Kepler-312         1.0372e+27
# Kepler-312 b                          0       Kepler-312         1.0372e+27
# Kepler-337 c                          0       Kepler-337        1.11571e+27
# Kepler-337 b                          0       Kepler-337        1.11571e+27
# GJ 536                                0           GJ 536        1.58894e+25
# Kepler-1094 b                         0      Kepler-1094         7.0424e+26
# Kepler-1142 b                         0      Kepler-1142        3.31804e+26
# Kepler-823 b                          0       Kepler-823        3.22106e+26
# Kepler-582 b                          0       Kepler-582        2.73557e+26
# HD 222076                             0        HD 222076        3.15176e+27
# WASP-122 b                1960        0         WASP-122        9.06022e+26
# FL Lyr b                              1           FL Lyr                nan
# HAT-P-21 b              1161.5        0         HAT-P-21        4.10362e+26
# Kepler-1359 b                         0      Kepler-1359        8.78611e+25
# HAT-P-67 b                            0         HAT-P-67        1.38734e+27
# HAT-P-34 b              1335.3        0         HAT-P-34        1.39867e+27
# Kepler-658 b                          0       Kepler-658        3.51662e+25
# eta Cet b                             0          eta Cet        2.96288e+28
# eta Cet c                             0          eta Cet        2.96288e+28
# HD 108874 b              256.8        0        HD 108874        4.38492e+26
# HD 108874 c              160.2        0        HD 108874        4.38492e+26
# Kepler-1473 b                         0      Kepler-1473        5.47195e+26
# Kepler-953 b                          0       Kepler-953        2.90671e+26
# Kepler-953 c                          0       Kepler-953        2.90671e+26
#
#                   HostStarInnerHabitabilityAU HostStarOuterHabitabilityAU
# PlanetIdentifier
# KOI-1843.03                          0.194521                    0.280237
# Kepler-974 b                         0.194521                    0.280237
# KOI-1843.02                          0.194521                    0.280237
# Kepler-9 b                           0.974217                     1.40351
# Kepler-9 c                           0.974217                     1.40351
# Kepler-9 d                           0.974217                     1.40351
# GJ 160.2 b                                nan                         nan
# Kepler-566 b                         0.595458                    0.857847
# WASP-124 b                                nan                         nan
# HD 240210 b                               nan                         nan
# OGLE-05-390L b                            nan                         nan
# Kepler-1343 b                         0.88273                     1.27171
# Kepler-1011 b                        0.738739                     1.06426
# WASP-82 b                             2.62783                     3.78578
# Gliese 1214 b                       0.0668958                   0.0963735
# CoRoT-30 b                           0.840496                     1.21086
# Kepler-153 b                         0.745498                       1.074
# Kepler-153 c                         0.745498                       1.074
# HD 4203 b                             1.23753                     1.78285
# HD 4203 c                             1.23753                     1.78285
# HD 179079 b                           1.38775                     1.99927
# Kepler-1368 b                         1.07811                     1.55317
# HD 187123 b                           1.10611                     1.59351
# HD 187123 c                           1.10611                     1.59351
# Kepler-1111 b                         1.21542                       1.751
# Kepler-1289 b                         1.23778                     1.78321
# KIC 5095269(AB) b                         nan                         nan
# Kepler-431 b                          1.12656                     1.62298
# Kepler-431 c                          1.12656                     1.62298
# Kepler-431 d                          1.12656                     1.62298
# ...                                       ...                         ...
# Kepler-1018 b                        0.766826                     1.10473
# CoRoT-8 b                            0.568682                    0.819271
# Kepler-1627 b                        0.712732                      1.0268
# Kepler-729 b                         0.826365                      1.1905
# KOI-89 b                              2.91823                     4.20415
# KOI-89.02                             2.91823                     4.20415
# Kepler-312 c                          1.56991                     2.26169
# Kepler-312 b                          1.56991                     2.26169
# Kepler-337 c                          1.62824                     2.34572
# Kepler-337 b                          1.62824                     2.34572
# GJ 536                                0.19431                    0.279933
# Kepler-1094 b                         1.29361                     1.86364
# Kepler-1142 b                        0.887939                     1.27921
# Kepler-823 b                         0.874868                     1.26038
# Kepler-582 b                         0.806244                     1.16152
# HD 222076                             2.73665                     3.94255
# WASP-122 b                            1.46728                     2.11383
# FL Lyr b                                  nan                         nan
# HAT-P-21 b                           0.987475                     1.42261
# Kepler-1359 b                        0.456921                    0.658263
# HAT-P-67 b                            1.81566                     2.61573
# HAT-P-34 b                            1.82306                     2.62639
# Kepler-658 b                         0.289072                    0.416451
# eta Cet b                             8.39073                     12.0881
# eta Cet c                             8.39073                     12.0881
# HD 108874 b                           1.02076                     1.47056
# HD 108874 c                           1.02076                     1.47056
# Kepler-1473 b                         1.14029                     1.64275
# Kepler-953 b                         0.831081                      1.1973
# Kepler-953 c                         0.831081                      1.1973
#
# [3657 rows x 18 columns]

# %%
for planet in planets:
    if 'rapp' in planet:
        print(planet)

# %%
# Out:
# 3584
